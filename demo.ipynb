# %%
import sys
import bs4 as bs
import numpy as np
import matplotlib
import scipy
import pandas
import Crypto
import pycodestyle
import pytest
import sklearn
import statsmodels
import sympy
import tensorflow as tf
import xlrd

print("Python is:", sys.version)
print("beautifulsoup4 is:", bs.__version__)
print("scipy is:", scipy.__version__)
print("numpy is:", np.__version__)
print("scipy is:", scipy.__version__)
print("pandas is:", pandas.__version__)
print("Matplotlib is:", matplotlib.__version__)
print("pycrypto is:", Crypto.__version__)
print("pycodestyle is:", pycodestyle.__version__)
print("pytest is:", pytest.__version__)
print("scikit-learn is:", sklearn.__version__)
print("statsmodels is:", statsmodels.__version__)
print("sympy is:", sympy.__version__)
print("tensorflow is:", tf.__version__)
print("xlrd is:", xlrd.__version__)
# Out:
# Python is: 3.7.12 | packaged by conda-forge | (default, Oct 26 2021, 06:08:21)
# [GCC 9.4.0]
# beautifulsoup4 is: 4.11.2
# scipy is: 1.7.3
# numpy is: 1.21.6
# scipy is: 1.7.3
# pandas is: 1.3.5
# Matplotlib is: 3.5.3
# pycrypto is: 2.6.1
# pycodestyle is: 2.10.0
# pytest is: 7.2.1
# scikit-learn is: 1.0.2
# statsmodels is: 0.13.5
# sympy is: 1.10.1
# tensorflow is: 2.11.0
# xlrd is: 2.0.1
